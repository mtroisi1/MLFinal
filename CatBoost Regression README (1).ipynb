# %%
# USA Real Estate Price Prediction

This project trains a regression model to predict residential property prices in the United States 
using publicly available data from Kaggle. The workflow is implemented in a Jupyter notebook (`Regression.ipynb`) 
and uses CatBoost, scikit-learn, pandas, and the Kaggle API.

---

## 1. Project Overview

The main goals of this project are:

- Load and explore a large real-estate dataset from Kaggle
- Prepare and clean the data for machine learning
- Train a gradient-boosted decision tree model (CatBoostRegressor) to predict house prices
- Evaluate the model on a held-out test set
- Provide a simple command-line function that lets a user enter house information and get an estimated price

---

## 2. Dataset

- Source: Kaggle dataset  
  `ahmedshahriarsakib/usa-real-estate-dataset`
    
- Downloaded file: `usa-real-estate-dataset.zip`
    
- Main CSV used: `usa-real-estate-dataset/realtor-data.zip.csv`

From this CSV, the notebook uses the following columns:

- `price` – target variable (property price in USD)
- `state` – U.S. state
- `city` – City of the property
- `zip_code` – zip code of the property
- `bed` – Number of bedrooms
- `bath` – Number of bathrooms
- `house_size` – House size in square feet

Rows with missing values in these columns are dropped for modeling

---

## 3. Requirements and Dependencies

The notebook installs and uses the following Python packages:

```bash
pip install kaggle pandas numpy scikit-learn catboost
